# %%
# get
from urllib import request
import requests

url = "http://www.weather.com.cn/weather15d/101190707.shtml"
response = requests.get(url)

print(response)
print("-----------------------------")
# print("response.text:\n{}".format(response.text))
print("-------------------------------------")
# print("resposne.content:\n{}".format(response.content))
print("---------------------------------------")
# print("response.content.decode('utf-8'):\n{}".format(response.content.decode('utf-8')))
print("---------------------------------------")
# response.cookies操作
# 返回RequestCookieJar对象
cookies = response.cookies
# RequestCookieJar to dict
cookies_dict = requests.utils.dict_from_cookiejar(cookies)
# dict to ReqeustCookieJar
# requests.utils.dict_from_cookiejar(xxx)
# 将一个字典添加到cookieJar中
# requests.utils.add_dict_to_cookiejar(xxxxx)
print("cookies_dict:\n{}".format(cookies_dict))
print("--------------------------------------")
# Out:
# <Response [200]>
# -----------------------------
# -------------------------------------
# ---------------------------------------
# ---------------------------------------
# cookies_dict:
# {'HttpOnly': None}
# --------------------------------------

# %%
# 自定义请求头,get请求数据
import requests

url = "https://www.douban.com/search"
# 自定义请求头
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"}
params = {"q": "阳光灿烂的日子"}
# get请求数据
response = requests.get(url, headers=headers)
print(response.content.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html lang="zh-cmn-Hans" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
#   搜索:
# </title>
#
#
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
# <link rel="search" type="application/opensearchdescription+xml" title="豆瓣搜索" href="/opensearch">
#
#     <script >var _head_start = new Date();</script>
#     <script src="https://img3.doubanio.com/f/shire/72ced6df41d4d158420cebdd254f9562942464e3/js/jquery.min.js"></script>
#     <script src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js"></script>
# ...

# %%
# 下载图片
import requests
url = "https://pic2.zhimg.com/v2-1c59abef181249e4c7e6a6114d4e5b9d_r.jpg"
response = requests.get(url)
with open("爬虫路线图.jpg", "wb") as f:
    f.write(response.content)

# %%
import urllib.request as request

url = "https://pic2.zhimg.com/v2-1c59abef181249e4c7e6a6114d4e5b9d_r.jpg"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"}

req = request.Request(url=url, headers=headers)

response = request.urlopen(req)

with open("tutut.jpg", "wb") as f:
    f.write(response.read())

# %%
import json

# json.loads json字符串 转 Python数据类型
json_string = '''
{
    "name": "crise",
    "age": 18,
    "parents": {
        "monther": "妈妈",
        "father": "爸爸"
    }
}
'''
print("json_string数据类型：",type(json_string))
data = json.loads(json_string)
print("data数据类型：",type(data))
print(data)
print("*" * 100)
# json.dumps Python数据类型 转 json字符串
data = {
    "name": "crise",
    "age": 18,
    "parents": {
        "mother": "妈妈",
        "father": "爸爸"
    }
}
print("data数据类型：",type(data))
json_string = json.dumps(data)
print("json_string数据类型：",type(json_string))
print(json_string)

print("*"*100)
# json.load json文件 转 Python数据类型
with open('data_out.json','r',encoding='utf-8') as f:
    data = json.load(f)
    print("data数据类型：", type(data))
    print(data)

print("*"*100)
# # json.dump Python数据类型 转 json文件
data = {
    "name": "crise",
    "age": 18,
    "parents": {
        "monther": "妈妈",
        "father": "爸爸"
    }
}
with open('data_out.json','w',encoding='utf-8') as f:
    json.dump(data,f,ensure_ascii=False,indent=2)
# Out:
# json_string数据类型： <class 'str'>
# data数据类型： <class 'dict'>
# {'name': 'crise', 'age': 18, 'parents': {'monther': '妈妈', 'father': '爸爸'}}
# ****************************************************************************************************
# data数据类型： <class 'dict'>
# json_string数据类型： <class 'str'>
# {"name": "crise", "age": 18, "parents": {"mother": "\u5988\u5988", "father": "\u7238\u7238"}}
# ****************************************************************************************************
# data数据类型： <class 'dict'>
# {'name': 'crise', 'age': 18, 'parents': {'monther': '妈妈', 'father': '爸爸'}}
# ****************************************************************************************************

# %%
# 网络获取数据
import requests
import json
import jsonpath

url = "http://www.lagou.com/lbs/getAllCitySearchLabels.json"
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36"
}

response = requests.get(url,headers=headers)
html = response.text
print(html)
# 把响应数据转换成python数据类型
data = json.loads(html)

# 使用 jsonpath 提取数据
cities = jsonpath.jsonpath(data,'$..name')
print(cities)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-74-ea279c2e2e21> in <module>
#       2 import requests
#       3 import json
# ----> 4 import jsonpath
#       5
#       6 url = "http://www.lagou.com/lbs/getAllCitySearchLabels.json"
#
# ModuleNotFoundError: No module named 'jsonpath'

# %%
# 豆瓣
import requests
import json
import numpy as np

# 定义请求url
url = "https://movie.douban.com/j/search_subjects"
# 定义请求头
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"
}

# 测试用拼接文字
# url += '?'
# params_list = list()
# for key, value in params.items():
#     params_list.append("{}={}".format(key, value))
# url += "&".join(params_list) 
# print(url)

# 循环构建请求参数并且发送请求
for page_start in np.arange(0, 100, 20):
    params = {
        "type": "movie",
        "tag": "热门",
        "sort": "recommend",
        "page_limit": "20",
        "page_start": page_start
    }
    
    response = requests.get(
        url=url,
        headers=headers,
        params=params
    )
    
    # 方式一:直接转换json方法
    results = response.json()
    # 方式二: 手动转换
    # 获取字节串
    # content = response.content
    # 转换成字符串
    # string = content.decode('utf-8')
    # 把字符串转成python数据类型
    # results = json.loads(string)
    
    # 解析结果
    for movie in results["subjects"]:
        print(movie["title"], movie["rate"])
# Out:
# 1917 8.5
# 囧妈 5.9
# 我的梦中情人 6.8
# 秘密动物园 6.4
# 丑女之战 6.1
# 寄生虫 8.7
# 小妇人 8.2
# 乔乔的异想世界 8.4
# 半个喜剧 7.4
# 阳光普照 8.4
# 小丑 8.7
# 爱尔兰人 8.9
# 婚姻故事 8.6
# 利刃出鞘 8.2
# 82年生的金智英 8.6
# 极速车王 8.5
# 好莱坞往事 7.3
# 只有芸知道 6.4
# 被光抓走的人 7.0
# 叶问4：完结篇 7.1
# 南方车站的聚会 7.4
# 宠爱 6.0
# 少年的你 8.3
# 两只老虎 6.0
# 黑水 8.4
# 亲爱的新年好 5.8
# 燃烧女子的肖像 8.6
# 平原上的夏洛克 7.9
# 地久天长 8.0
# 中国机长 6.7
# 我和我的祖国 7.8
# 哪吒之魔童降世 8.5
# 冰雪奇缘2 7.2
# 纽约的一个雨天 7.5
# 决战中途岛 7.7
# 双子杀手 6.9
# 多哥 8.8
# 罗小黑战记 8.2
# 理查德·朱维尔的哀歌 8.3
# 恶人传 7.7
# 沉睡魔咒2 6.1
# 教宗的承继 8.6
# 攀登者 6.1
# 朱迪 7.4
# 痛苦与荣耀 8.5
# 玩具总动员4 8.6
# 受益人 6.6
# 白头山 6.5
# 吹哨人 5.5
# 疾速备战 7.8
# 原钻 7.2
# 爆炸新闻 7.0
# 安娜 7.7
# 普罗米亚 8.5
# 终结者：黑暗命运 7.0
# 复仇者联盟4：终局之战 8.5
# 唐顿庄园 8.1
# 克劳斯：圣诞节的秘密 8.6
# 布鲁克林秘案 7.0
# 我在雨中等你 8.2
# 送我上青云 7.1
# 星际探索 6.9
# 狮子王 7.3
# 灯塔 7.2
# 睡梦医生 6.9
# 大约在冬季 5.1
# 基督圣体 7.6
# 极限逃生 7.5
# 我的一级兄弟 8.3
# 银河补习班 6.3
# 对不起，我们错过了你 8.2
# 肥龙过江 4.7
# 烈火英雄 6.5
# 柳烈的音乐专辑 7.8
# 法医宋慈 5.8
# 小委托人 8.1
# 邻里美好的一天 6.7
# 行骗天下JP：浪漫篇 8.1
# 我失去了身体 8.1
# 航海王：狂热行动 7.7
# 多力特的奇幻冒险 5.6
# 阿拉丁 7.5
# 大侦探皮卡丘 6.5
# ...

# %%
# 百度贴吧爬虫
import requests

class TiebaSpider():
    def __init__(self, kw, max_pn):
        self.max_pn = max_pn
        self.kw = kw
        self.base_url = "https://tieba.baidu.com/f?kw={}&ie=utf-8&pn={}"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"
        }
        
    def get_url_list(self):
        return [self.base_url.format(self.kw, pn) for pn in range(0, self.max_pn, 50)]
    
    def get_content(self, url):
        response = requests.get(
            url = url,
            headers = self.headers
        )
        return response.content
    
    def get_items(self, content, idx):
        with open("8-{}.html".format(idx), 'wb') as f:
            f.write(content)
        return None
    
    def save_items(self, items):
        pass
    
    def run(self):
        url_list = self.get_url_list()
        
        for url in url_list:
            content = self.get_content(url)
            
            items = self.get_items(content, url_list.index(url)+1)
            
            self.save_items(items)
        
        pass

if __name__ == '__main__':
    spider = TiebaSpider("英雄联盟", 150)
    spider.run()
